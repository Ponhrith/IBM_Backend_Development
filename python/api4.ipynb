# %%
import requests
import pandas as pd
import json

# %%
data = requests.get('https://official-joke-api.appspot.com/jokes/ten')

# %%
results = json.loads(data.text)
pd.DataFrame(results)
df = pd.json_normalize(results)
df
# Out:
#           type                                              setup  \
# 0      general  What do you call an Argentinian with a rubber ...
# 1      general  Did you hear about the new restaurant on the m...
# 2      general                            Why did the cookie cry?
# 3      general  Why do scuba divers fall backwards into the wa...
# 4      general          Why did the chicken cross the playground?
# 5      general                                   Where’s the bin?
# 6      general  A grocery store cashier asked if I would like ...
# 7  programming               Why did the programmer quit his job?
# 8      general  Did you hear about the Viking who was reincarn...
# 9  programming               How do you generate a random string?
#
#                                            punchline   id
# 0                                            Roberto  218
# 1  The food is great, but there’s just no atmosph...   92
# 2             Because his mother was a wafer so long  320
# 3  Because if they fell forwards they’d still be ...  351
# 4                         To get to the other slide.  428
# 5                           I haven’t been anywhere!  294
# 6    I told her 'No, thanks. The carton works fine.'  397
# 7                      Because he didn't get arrays.   18
# 8                                 He was Bjorn again  392
# 9  Put a Windows user in front of Vim and tell th...  405
