# %%
from randomuser import RandomUser
import pandas as pd


# Generate random users
r = RandomUser()


some_list = r.generate_users(10)
some_list
name = r.get_full_name()
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Ava Young   ava.young@example.com
# Daniel Manninen   daniel.manninen@example.com
# Ceylan Orbay   ceylan.orbay@example.com
# طاها مرادی   th.mrdy@example.com
# Afşar Erbay   afsar.erbay@example.com
# Oliver Walker   oliver.walker@example.com
# Christoffer Wiik   christoffer.wiik@example.com
# Sadie Roberts   sadie.roberts@example.com
# Max Hunt   max.hunt@example.com
# Renate Fabre   renate.fabre@example.com

# %%
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/67.jpg
# https://randomuser.me/api/portraits/men/19.jpg
# https://randomuser.me/api/portraits/women/54.jpg
# https://randomuser.me/api/portraits/men/14.jpg
# https://randomuser.me/api/portraits/women/39.jpg
# https://randomuser.me/api/portraits/men/15.jpg
# https://randomuser.me/api/portraits/men/61.jpg
# https://randomuser.me/api/portraits/women/6.jpg
# https://randomuser.me/api/portraits/men/4.jpg
# https://randomuser.me/api/portraits/women/83.jpg

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                Name  Gender            City         State  \
# 0        Konsta Oja    male      Pudasjärvi  Ostrobothnia
# 1    Julio De Smidt    male          Dieren       Limburg
# 2   Salvador Torres    male      Clearwater       Montana
# 3   Kadir Topaloğlu    male         Kocaeli       Isparta
# 4    Eemeli Pakkala    male        Utajärvi     Pirkanmaa
# 5     Ramona Duncan  female  Pembroke Pines        Kansas
# 6   Andresa Rezende  female         Pelotas     Tocantins
# 7  Alarico Teixeira    male            Embu          Pará
# 8   Laurie Kowalski  female      Cumberland      Manitoba
# 9       Blake Banks    male        Stirling       Borders
#
#                           Email                       DOB  \
# 0        konsta.oja@example.com  1977-05-13T02:10:54.985Z
# 1     julio.desmidt@example.com  1984-11-19T06:51:56.027Z
# 2   salvador.torres@example.com  1984-04-30T15:37:29.162Z
# 3   kadir.topaloglu@example.com  1988-12-17T21:22:22.892Z
# 4    eemeli.pakkala@example.com  1953-12-30T15:54:55.195Z
# 5     ramona.duncan@example.com  1982-04-16T09:08:40.249Z
# 6   andresa.rezende@example.com  1956-03-29T12:38:01.088Z
# 7  alarico.teixeira@example.com  1967-08-21T12:52:55.889Z
# 8   laurie.kowalski@example.com  1950-11-01T05:49:12.957Z
# 9       blake.banks@example.com  1991-01-14T18:17:12.283Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/60.jpg
# 1    https://randomuser.me/api/portraits/men/28.jpg
# 2    https://randomuser.me/api/portraits/men/43.jpg
# 3    https://randomuser.me/api/portraits/men/71.jpg
# 4    https://randomuser.me/api/portraits/men/74.jpg
# 5  https://randomuser.me/api/portraits/women/29.jpg
# 6  https://randomuser.me/api/portraits/women/18.jpg
# 7    https://randomuser.me/api/portraits/men/90.jpg
# 8  https://randomuser.me/api/portraits/women/59.jpg
# 9    https://randomuser.me/api/portraits/men/83.jpg

# %%
df1 = pd.DataFrame(get_users())
